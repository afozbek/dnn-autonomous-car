# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)

points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)

plt.scatter(X, y)

# %%
model = Sequential()
#X value input
model.add(Dense(units=50, activation='sigmoid', input_dim=1 ))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1)) #single output
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 50)                100
# _________________________________________________________________
# dense_20 (Dense)             (None, 30)                1530
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 1,661
# Trainable params: 1,661
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)#mean square error
model.fit(X, y, epochs=15)
# Out:
# Epoch 1/15
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4538
# Epoch 2/15
# 500/500 [==============================] - 0s 47us/step - loss: 0.2398
# Epoch 3/15
# 500/500 [==============================] - 0s 51us/step - loss: 0.2613
# Epoch 4/15
# 500/500 [==============================] - 0s 56us/step - loss: 0.2255
# Epoch 5/15
# 500/500 [==============================] - 0s 55us/step - loss: 0.2280
# Epoch 6/15
# 500/500 [==============================] - 0s 45us/step - loss: 0.2249
# Epoch 7/15
# 500/500 [==============================] - 0s 41us/step - loss: 0.2175
# Epoch 8/15
# 500/500 [==============================] - 0s 48us/step - loss: 0.2198
# Epoch 9/15
# 500/500 [==============================] - 0s 45us/step - loss: 0.2042
# Epoch 10/15
# 500/500 [==============================] - 0s 45us/step - loss: 0.1903
# Epoch 11/15
# 500/500 [==============================] - 0s 53us/step - loss: 0.1901
# Epoch 12/15
# 500/500 [==============================] - 0s 51us/step - loss: 0.1768
# Epoch 13/15
# 500/500 [==============================] - 0s 41us/step - loss: 0.1672
# Epoch 14/15
# 500/500 [==============================] - 0s 53us/step - loss: 0.1564
# Epoch 15/15
# 500/500 [==============================] - 0s 46us/step - loss: 0.1540

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
